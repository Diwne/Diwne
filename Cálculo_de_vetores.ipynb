# %% [markdown]
# <a href="https://colab.research.google.com/github/Diwne/Diwne/blob/main/C%C3%A1lculo_de_vetores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calcular a norma de um vetor

import numpy as np
A = np.array([3,4])
norma = np.linalg.norm(A)
print("Norma de [3,4]:", norma)
# Out:
# Norma de [3,4]: 5.0
